# %%
import os
from nilmtk import DataSet
import warnings
warnings.filterwarnings("ignore")

# %%
file_name = os.path.join('data','III_2017-10-09.h5')
III = DataSet( file_name )

# %%
III.buildings
# Out:
# OrderedDict([(1, Building(instance=1, dataset='III')),
#              (2, Building(instance=2, dataset='III')),
#              (3, Building(instance=3, dataset='III')),
#              (4, Building(instance=4, dataset='III')),
#              (5, Building(instance=5, dataset='III')),
#              (6, Building(instance=6, dataset='III')),
#              (7, Building(instance=7, dataset='III')),
#              (8, Building(instance=8, dataset='III'))])

# %%
building_number = 1
elec_1 = III.buildings[1].elec

# %%
from pylab import rcParams
import matplotlib.pyplot as plt
# %matplotlib inline
rcParams['figure.figsize'] = (16, 8)

# %% [markdown]
# ### Plot for whole data of building1

# %%
elec_1.plot()
plt.show()

# %% [markdown]
# ### Plot for a single day of building1

# %%
from nilmtk import TimeFrame
III.store.window = TimeFrame(start='2017-09-01 00:00:00-05:00', end='2017-09-02 00:00:00-05:00')
elec_1.plot()
plt.show()

# %% [markdown]
# ### Plot for a single day of building2

# %%
elec_2 = III.buildings[2].elec
elec_2.plot()
plt.show()

# %% [markdown]
# ### Plot for a single day of building3

# %%
elec_3 = III.buildings[3].elec
elec_3.plot()
plt.show()

# %% [markdown]
# ### Plot for a single day of building4

# %%
elec_4 = III.buildings[4].elec
elec_4.plot()
plt.show()

# %% [markdown]
# ### Plot for a single day of building5

# %%
elec_5 = III.buildings[5].elec
elec_5.plot()
plt.show()

# %%
elec_6 = III.buildings[6].elec
elec_6.plot()
plt.show()

# %% [markdown]
# ### Plot for a single day of building7

# %%
elec_7 = III.buildings[7].elec
elec_7.plot()
plt.show()

# %% [markdown]
# ### Plot for a single day of building8

# %%
elec_8 = III.buildings[8].elec
elec_8.plot()
plt.show()
