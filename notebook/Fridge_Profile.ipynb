# %% [markdown]
# ## Profile for Fridge

# %% [markdown]
# ### We need to record the profile of each fridge to get a "good" batch of samples when using neuralnilm.

# %%
import os
from nilmtk import DataSet
import warnings
warnings.filterwarnings("ignore")

from pylab import rcParams
import matplotlib.pyplot as plt
# %matplotlib inline
rcParams['figure.figsize'] = (16, 8)

# %% [markdown]
# ## HEMS_PongHu

# %%
file_name = os.path.join('data','HEMS','HEMS_PongHu2017-11-03.h5',)
III = DataSet( file_name )

# %% [markdown]
# ## Check for Fridge in One day

# %%
Target = 'fridge'
III.set_window("2015-09-04", "2015-09-05")

# %% [markdown]
# ### house_1

# %%
building_number = 1
elec_1 = III.buildings[1].elec
elec_1[Target].plot()
plt.show()
#elec_1['fridge'].get_activations()

# %% [markdown]
# ### house_2

# %%
elec_2 = III.buildings[2].elec
elec_2[Target].plot()
plt.show()

# %% [markdown]
# ### house_3

# %%
elec_3 = III.buildings[3].elec
elec_3[Target].plot()
plt.show()

# %% [markdown]
# ### house_4

# %%
elec_4 = III.buildings[4].elec
elec_4[Target].plot()
plt.show()

# %% [markdown]
# ### house_5

# %%
elec_5 = III.buildings[5].elec
elec_5[Target].plot()
plt.show()

# %% [markdown]
# ### house_6

# %%
elec_6 = III.buildings[6].elec
elec_6[Target].plot()
plt.show()

# %% [markdown]
# ### house_7

# %%
elec_7 = III.buildings[7].elec
elec_7[Target].plot()
plt.show()

# %% [markdown]
# ### house_8

# %%
elec_8 = III.buildings[8].elec
elec_8[Target].plot()
plt.show()

# %% [markdown]
# ### house_9

# %%
elec_9 = III.buildings[9].elec
elec_9[Target].plot()
plt.show()

# %% [markdown]
# ### house_10

# %%
elec_10 = III.buildings[10].elec
elec_10[Target].plot()
plt.show()

# %% [markdown]
# ### house_11

# %%
elec_11 = III.buildings[11].elec
elec_11[Target].plot()
plt.show()

# %% [markdown]
# ### Across from 2015/09/01 to 2016/02/28 : We can see the seasonal change

# %%
III.set_window("2015-09-01", "2016-02-28")

# %% [markdown]
# ### house_1

# %%
elec_1[Target].plot()
plt.show()

# %% [markdown]
# ### house_2

# %%
elec_2[Target].plot()
plt.show()

# %% [markdown]
# ### house_3

# %%
elec_3[Target].plot()
plt.show()

# %% [markdown]
# ### house_4

# %%
elec_4[Target].plot()
plt.show()

# %% [markdown]
# ### house_4

# %%
elec_4elec_1[Target].plot()
plt.show()[Target].plot()
plt.show()

# %% [markdown]
# ### house_5

# %%
elec_5[Target].plot()
plt.show()

# %% [markdown]
# ### house_6

# %%
elec_6[Target].plot()
plt.show()

# %% [markdown]
# ### house_7

# %%
elec_7[Target].plot()
plt.show()

# %% [markdown]
# ### house_8

# %%
elec_8[Target].plot()
plt.show()

# %% [markdown]
# ### house_9

# %%
elec_9[Target].plot()
plt.show()

# %% [markdown]
# ### house_10

# %%
elec_10[Target].plot()
plt.show()

# %% [markdown]
# ### house_11

# %%
elec_11[Target].plot()
plt.show()
